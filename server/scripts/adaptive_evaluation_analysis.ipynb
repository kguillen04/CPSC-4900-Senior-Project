# %%
import pandas as pd
import matplotlib.pyplot as plt 
import glob
import os

# %%
# OUTPUT_DIR = "scripts/evaluation-output"
OUTPUT_DIR = "/Users/simonscholar/Desktop/CPSC-4900-Senior-Project/server/evaluation-output"

def find_latest(pattern):
    files = glob.glob(os.path.join(OUTPUT_DIR, pattern))
    basenames = [os.path.basename(f) for f in files]
    print("Found files:", basenames)

    if not files:
        raise ValueError(f"No files found for pattern: {pattern}")

    latest = max(files, key=lambda f: os.path.basename(f))
    print("Chosen file:", os.path.basename(latest))
    return latest

attempt_csv = find_latest("adaptive-eval-attempts-*.csv")
session_csv = find_latest("adaptive-eval-sessions-*.csv")

attempt_df = pd.read_csv(attempt_csv)
session_df = pd.read_csv(session_csv)

attempt_df.head()
# Out:
# Found files: ['adaptive-eval-attempts-2026-04-07T20-59-03-754Z.csv', 'adaptive-eval-attempts-2026-04-07T20-40-47-250Z.csv', 'adaptive-eval-attempts-2026-04-07T20-41-11-755Z.csv', 'adaptive-eval-attempts-2026-04-07T21-28-21-223Z.csv', 'adaptive-eval-attempts-2026-04-07T21-00-16-980Z.csv', 'adaptive-eval-attempts-2026-04-08T15-40-03-215Z.csv']
# Chosen file: adaptive-eval-attempts-2026-04-08T15-40-03-215Z.csv
# Found files: ['adaptive-eval-sessions-2026-04-07T20-40-47-250Z.csv', 'adaptive-eval-sessions-2026-04-07T20-59-03-754Z.csv', 'adaptive-eval-sessions-2026-04-07T21-00-16-980Z.csv', 'adaptive-eval-sessions-2026-04-07T21-28-21-223Z.csv', 'adaptive-eval-sessions-2026-04-07T20-41-11-755Z.csv', 'adaptive-eval-sessions-2026-04-08T15-40-03-215Z.csv']
# Chosen file: adaptive-eval-sessions-2026-04-08T15-40-03-215Z.csv
#    trial     profile    policy    concept  attempt  sessionLength  \
# 0      1  Struggling  adaptive  variables        1            100
# 1      1  Struggling  adaptive  variables        2            100
# 2      1  Struggling  adaptive  variables        3            100
# 3      1  Struggling  adaptive  variables        4            100
# 4      1  Struggling  adaptive  variables        5            100
#
#                  questionId  difficulty  targetDifficulty  selectionMode  \
# 0  69c0436a41a5009b15c78b1d           3                 3            NaN
# 1  69c0436a41a5009b15c78b1c           3                 3            NaN
# 2  69c0436a41a5009b15c78b20           4                 4            NaN
# 3  69c0436a41a5009b15c78b1b           3                 3            NaN
# 4  69c0436a41a5009b15c78b1a           2                 2            NaN
#
#    probabilityCorrect  correct  selectedIndex  correctIndex  oldMastery  \
# 0                0.25    False              2             0       0.500
# 1                0.25     True              0             0       0.461
# 2                0.15    False              0             2       0.509
# 3                0.25     True              1             1       0.481
# 4                0.40     True              2             2       0.525
#
#    newMastery  delta
# 0       0.461 -0.039
# 1       0.509  0.048
# 2       0.481 -0.028
# 3       0.525  0.045
# 4       0.549  0.023

# %%
numeric_cols = [
    "trial",
    "questionsAnswered",
    "numCorrect",
    "accuracy",
    "startingMastery",
    "endingMastery",
    "masteryGain",
    "avgDifficulty"
]

for col in numeric_cols:
    session_df[col] = pd.to_numeric(session_df[col])

# %%
summary = (
    session_df
    .groupby(["profile", "policy", "concept"])
    .agg({
        "endingMastery": "mean",
        "masteryGain": "mean",
        "accuracy": "mean",
        "avgDifficulty": "mean"
    })
    .reset_index()
)

summary
# Out:
#        profile    policy       concept  endingMastery  masteryGain  accuracy  \
# 0    Improving  adaptive  conditionals       0.528867     0.028867  0.517333
# 1    Improving  adaptive         loops       0.516967     0.016967  0.503333
# 2    Improving  adaptive     variables       0.526400     0.026400  0.514667
# 3    Improving    random  conditionals       0.539033     0.039033  0.528667
# 4    Improving    random         loops       0.516067     0.016067  0.527667
# 5    Improving    random     variables       0.514833     0.014833  0.501000
# 6       Strong  adaptive  conditionals       0.699600     0.199600  0.761667
# 7       Strong  adaptive         loops       0.696600     0.196600  0.753333
# 8       Strong  adaptive     variables       0.689867     0.189867  0.737333
# 9       Strong    random  conditionals       0.683100     0.183100  0.795667
# 10      Strong    random         loops       0.663667     0.163667  0.804667
# 11      Strong    random     variables       0.643833     0.143833  0.791667
# 12  Struggling  adaptive  conditionals       0.390933    -0.109067  0.323667
# 13  Struggling  adaptive         loops       0.379400    -0.120600  0.318000
# 14  Struggling  adaptive     variables       0.389367    -0.110633  0.317667
# 15  Struggling    random  conditionals       0.370633    -0.129367  0.287000
# 16  Struggling    random         loops       0.367700    -0.132300  0.269333
# 17  Struggling    random     variables       0.407733    -0.092267  0.275667
#
#     avgDifficulty
# 0        3.080333
# 1        3.046000
# 2        3.076333
# 3        2.986333
# 4        3.002000
# 5        3.027000
# 6        3.567000
# 7        3.544667
# 8        3.571000
# 9        2.977667
# 10       2.953667
# 11       2.967000
# 12       2.618333
# 13       2.585667
# 14       2.611000
# 15       2.985000
# 16       3.027000
# 17       3.031333

# %%
overall_summary = (
    session_df
    .groupby(["profile", "policy"])
    .agg({
        "endingMastery": "mean",
        "masteryGain": "mean",
        "accuracy": "mean",
        "avgDifficulty": "mean"
    })
    .reset_index()
)

overall_summary
# Out:
#       profile    policy  endingMastery  masteryGain  accuracy  avgDifficulty
# 0   Improving  adaptive       0.524078     0.024078  0.511778       3.067556
# 1   Improving    random       0.523311     0.023311  0.519111       3.005111
# 2      Strong  adaptive       0.695356     0.195356  0.750778       3.560889
# 3      Strong    random       0.663533     0.163533  0.797333       2.966111
# 4  Struggling  adaptive       0.386567    -0.113433  0.319778       2.605000
# 5  Struggling    random       0.382022    -0.117978  0.277333       3.014444

# %%
for concept in summary["concept"].unique():
    concept_df = summary[summary["concept"] == concept]
    pivot = concept_df.pivot(index="profile", columns="policy", values="endingMastery")

    pivot.plot(kind="bar")
    plt.title(f"Average Ending Mastery by Profile and Policy — {concept}")
    plt.ylabel("Ending Mastery")
    plt.ylim(0, 1)
    plt.xticks(rotation=0)
    plt.legend(title="Policy")
    plt.show()

# %%
pivot = overall_summary.pivot(index="profile", columns="policy", values="endingMastery")

pivot.plot(kind="bar")
plt.title("Average Ending Mastery by Profile and Policy")
plt.ylabel("Ending Mastery")
plt.ylim(0, 1)
plt.xticks(rotation=0)
plt.legend(title="Policy")
plt.show()

# %%
for concept in summary["concept"].unique():
    concept_df = summary[summary["concept"] == concept]
    pivot = concept_df.pivot(index="profile", columns="policy", values="masteryGain")

    pivot.plot(kind="bar")
    plt.title(f"Average Mastery Gain by Profile and Policy — {concept}")
    plt.ylabel("Mastery Gain")
    plt.xticks(rotation=0)
    plt.axhline(0)
    plt.legend(title="Policy")
    plt.show()

# %%
pivot = overall_summary.pivot(index="profile", columns="policy", values="masteryGain")

pivot.plot(kind="bar")
plt.title("Average Mastery Gain by Profile and Policy")
plt.ylabel("Mastery Gain")
plt.xticks(rotation=0)
plt.axhline(0)
plt.legend(title="Policy")
plt.show()

# %%
for concept in summary["concept"].unique():
    concept_df = summary[summary["concept"] == concept]
    pivot = concept_df.pivot(index="profile", columns="policy", values="avgDifficulty")

    pivot.plot(kind="bar")
    plt.title(f"Average Difficulty by Profile and Policy — {concept}")
    plt.ylabel("Average Difficulty")
    plt.ylim(1, 5)
    plt.xticks(rotation=0)
    plt.legend(title="Policy")
    plt.show()

# %%
pivot = overall_summary.pivot(index="profile", columns="policy", values="avgDifficulty")

pivot.plot(kind="bar")
plt.title("Average Difficulty by Profile and Policy")
plt.ylabel("Average Difficulty")
plt.ylim(1, 5)
plt.xticks(rotation=0)
plt.legend(title="Policy")
plt.show()

# %%
comparison_table = (
    session_df
    .groupby(["profile", "policy"])
    .agg({
        "endingMastery": ["mean", "std"],
        "masteryGain": ["mean", "std"],
        "accuracy": ["mean", "std"],
        "avgDifficulty": ["mean", "std"]
    })
    .round(3)
)

comparison_table
# Out:
#                     endingMastery        masteryGain        accuracy         \
#                              mean    std        mean    std     mean    std
# profile    policy
# Improving  adaptive         0.524  0.076       0.024  0.076    0.512  0.046
#            random           0.523  0.072       0.023  0.072    0.519  0.045
# Strong     adaptive         0.695  0.066       0.195  0.066    0.751  0.039
#            random           0.664  0.059       0.164  0.059    0.797  0.039
# Struggling adaptive         0.387  0.068      -0.113  0.068    0.320  0.038
#            random           0.382  0.059      -0.118  0.059    0.277  0.048
#
#                     avgDifficulty
#                              mean    std
# profile    policy
# Improving  adaptive         3.068  0.108
#            random           3.005  0.129
# Strong     adaptive         3.561  0.095
#            random           2.966  0.123
# Struggling adaptive         2.605  0.130
#            random           3.014  0.114

# %%
attempt_df["attempt"] = pd.to_numeric(attempt_df["attempt"])
attempt_df["difficulty"] = pd.to_numeric(attempt_df["difficulty"])
attempt_df["newMastery"] = pd.to_numeric(attempt_df["newMastery"])

# %%
attempt_df["bin"] = ((attempt_df["attempt"] - 1) // 10) * 10 + 1

# %%
grouped = (
    attempt_df
    .groupby(["profile", "policy", "concept", "bin"])
    .agg({"newMastery": "mean"})
    .reset_index()
)

for concept in grouped["concept"].unique():
    for profile in grouped["profile"].unique():
        plt.figure()

        subset = grouped[
            (grouped["concept"] == concept) &
            (grouped["profile"] == profile)
        ]

        for policy in subset["policy"].unique():
            df = subset[subset["policy"] == policy].sort_values("bin")
            plt.plot(df["bin"], df["newMastery"], marker="o", label=policy)

        plt.title(f"Mastery Over Time — {profile} — {concept}")
        plt.xlabel("Attempts (grouped by 10)")
        plt.ylabel("Average Mastery")
        plt.ylim(0, 1)
        plt.legend()
        plt.show()

# %%
grouped = (
    attempt_df
    .groupby(["profile", "policy", "concept", "bin"])
    .agg({"difficulty": "mean"})
    .reset_index()
)

for concept in grouped["concept"].unique():
    for profile in grouped["profile"].unique():
        plt.figure()

        subset = grouped[
            (grouped["concept"] == concept) &
            (grouped["profile"] == profile)
        ]

        for policy in subset["policy"].unique():
            df = subset[subset["policy"] == policy].sort_values("bin")
            plt.plot(df["bin"], df["difficulty"], marker="o", label=policy)

        plt.title(f"Difficulty Over Time — {profile} — {concept}")
        plt.xlabel("Attempts (grouped by 10)")
        plt.ylabel("Average Difficulty")
        plt.ylim(1, 5)
        plt.legend()
        plt.show()

# %%
grouped = (
    attempt_df
    .groupby(["profile", "policy", "bin"])
    .agg({"newMastery": "mean"})
    .reset_index()
)

for profile in grouped["profile"].unique():
    plt.figure()

    subset = grouped[grouped["profile"] == profile]

    for policy in subset["policy"].unique():
        df = subset[subset["policy"] == policy].sort_values("bin")
        plt.plot(df["bin"], df["newMastery"], marker="o", label=policy)

    plt.title(f"Mastery Over Time — {profile}")
    plt.xlabel("Attempts (grouped by 10)")
    plt.ylabel("Average Mastery")
    plt.ylim(0, 1)
    plt.legend()
    plt.show()

# %%
grouped = (
    attempt_df
    .groupby(["profile", "policy", "bin"])
    .agg({"difficulty": "mean"})
    .reset_index()
)

for profile in grouped["profile"].unique():
    plt.figure()

    subset = grouped[grouped["profile"] == profile]

    for policy in subset["policy"].unique():
        df = subset[subset["policy"] == policy].sort_values("bin")
        plt.plot(df["bin"], df["difficulty"], marker="o", label=policy)

    plt.title(f"Difficulty Over Time — {profile}")
    plt.xlabel("Attempts (grouped by 10)")
    plt.ylabel("Average Difficulty")
    plt.ylim(1, 5)
    plt.legend()
    plt.show()
